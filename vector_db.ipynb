# %%
import chromadb
client = chromadb.Client()

# %%
collection = client.create_collection("news_articles")

# %%
collection.add(
    ids = ["id1", "id2", "id3", "id4"],
    documents = [
        "Apple is leading in a smart phone game with iphone sales up by 35%",
        "Tesla booked minor profit of 1 billion $ in Q2",
        "Apples are high in fiber, vitamin C and various antioxidants",
        "SpaceX got NASA contracts worth 10 billion $",
    ])
# Out:
# C:\Users\Sharad\.cache\chroma\onnx_models\all-MiniLM-L6-v2\onnx.tar.gz: 100%|██████████| 79.3M/79.3M [06:15<00:00, 222kiB/s]

# %%
data = collection.get(
    include = ["documents", "embeddings", "metadatas"]
)

for i , emb in enumerate(data["embeddings"]):
    print(f"\nDocuments{i+1}")
    print("Text: ", data["documents"][i])
    print("Embeddings length: ", len(emb))
    print("first 10 values: ", emb[:10])
# Out:
# Documents1
# Text:  Apple is leading in a smart phone game with iphone sales up by 35%
# Embeddings length:  384
# first 10 values:  [ 0.03640457  0.01021045  0.08642431 -0.12735225 -0.01895926  0.00309625
#   0.01671755  0.05566161  0.02376828  0.11325454]
#
# Documents2
# Text:  Tesla booked minor profit of 1 billion $ in Q2
# Embeddings length:  384
# first 10 values:  [ 0.03671652  0.09181681  0.02858083  0.07864864 -0.0665484  -0.03148241
#  -0.0292116   0.10107821  0.02567091  0.02330876]
#
# Documents3
# Text:  Apples are high in fiber, vitamin C and various antioxidants
# Embeddings length:  384
# first 10 values:  [ 0.04282146 -0.02908744  0.01251418  0.08055454  0.00226209  0.02243376
#  -0.00943858 -0.01025315  0.00157953  0.01852741]
#
# Documents4
# Text:  SpaceX got NASA contracts worth 10 billion $
# Embeddings length:  384
# first 10 values:  [-0.01019068  0.02260832  0.0503177  -0.02799585 -0.08095403 -0.03154846
#   0.08039679  0.05077022  0.02780467  0.07230821]

# %%
result = collection.query(
    query_texts = ["rocket"],
    n_results = 2
)

print(result)
# Out:
# {'ids': [['id4', 'id2']], 'embeddings': None, 'documents': [['SpaceX got NASA contracts worth 10 billion $', 'Tesla booked minor profit of 1 billion $ in Q2']], 'uris': None, 'included': ['metadatas', 'documents', 'distances'], 'data': None, 'metadatas': [[None, None]], 'distances': [[1.487074375152588, 1.755058765411377]]}
